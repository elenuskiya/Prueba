# %%
import pandas as pd

# %%
print("probando probando")
# Out:
# probando probando

# %%
######## DATA #########

# %%
stations=pd.read_excel("Sample_stations.xlsx")
stations.head()
# Out:
#   SAMPLE\nSTATION ID  POINT ID RIVER OR\nLAKE/DAM  \
# 0          A1H001Q01       NaN              RIVER
# 1          A1H002Q01       NaN              RIVER
# 2          A1H003Q01       NaN              RIVER
# 3          A1H004Q01       NaN              RIVER
# 4          A1H005Q01       NaN              RIVER
#
#        BRIEF LOCALITY DESCRIPTION OF SAMPLE STATION SOUTH LAT.\nDEGR/MIN/SEC  \
# 0  DINOKANA UPPER EYE AT DINOKANA (AT PUMP STATION)               25  27  21
# 1           DINOKANA LOWER EYE AT DINOKANA (AT DAM)               25  26  53
# 2              TWEEFONTEIN UPPER EYE AT TWEEFONTEIN               25  32  42
# 3    TWEEFONTEIN LOWER EYE AT TWEEFONTEIN (AT ROAD)               25  32  39
# 4            SKILPAD EYE AT MOILWAS (AT STOCK-YARD)               25  19  52
#
#   SOUTH LON.\nDEGR/MIN/SEC  SOUTH LAT.\nDECIMAL DEGR  \
# 0               25  51  14                   25.4558
# 1               25  52  44                   25.4481
# ...

# %%
stations.rename({"SAMPLE\nSTATION ID": "Station"}, axis=1, inplace=True)

# %%
stations.head()
# Out:
#      Station  POINT ID RIVER OR\nLAKE/DAM  \
# 0  A1H001Q01       NaN              RIVER
# 1  A1H002Q01       NaN              RIVER
# 2  A1H003Q01       NaN              RIVER
# 3  A1H004Q01       NaN              RIVER
# 4  A1H005Q01       NaN              RIVER
#
#        BRIEF LOCALITY DESCRIPTION OF SAMPLE STATION SOUTH LAT.\nDEGR/MIN/SEC  \
# 0  DINOKANA UPPER EYE AT DINOKANA (AT PUMP STATION)               25  27  21
# 1           DINOKANA LOWER EYE AT DINOKANA (AT DAM)               25  26  53
# 2              TWEEFONTEIN UPPER EYE AT TWEEFONTEIN               25  32  42
# 3    TWEEFONTEIN LOWER EYE AT TWEEFONTEIN (AT ROAD)               25  32  39
# 4            SKILPAD EYE AT MOILWAS (AT STOCK-YARD)               25  19  52
#
#   SOUTH LON.\nDEGR/MIN/SEC  SOUTH LAT.\nDECIMAL DEGR  \
# 0               25  51  14                   25.4558
# 1               25  52  44                   25.4481
# 2               25  56  07                   25.5450
# ...

# %%
stations.to_excel("stations_modificated.xlsx", index=False)

# %%
stations.head()
# Out:
#      Station  POINT ID RIVER OR\nLAKE/DAM  \
# 0  A1H001Q01       NaN              RIVER
# 1  A1H002Q01       NaN              RIVER
# 2  A1H003Q01       NaN              RIVER
# 3  A1H004Q01       NaN              RIVER
# 4  A1H005Q01       NaN              RIVER
#
#        BRIEF LOCALITY DESCRIPTION OF SAMPLE STATION SOUTH LAT.\nDEGR/MIN/SEC  \
# 0  DINOKANA UPPER EYE AT DINOKANA (AT PUMP STATION)               25  27  21
# 1           DINOKANA LOWER EYE AT DINOKANA (AT DAM)               25  26  53
# 2              TWEEFONTEIN UPPER EYE AT TWEEFONTEIN               25  32  42
# 3    TWEEFONTEIN LOWER EYE AT TWEEFONTEIN (AT ROAD)               25  32  39
# 4            SKILPAD EYE AT MOILWAS (AT STOCK-YARD)               25  19  52
#
#   SOUTH LON.\nDEGR/MIN/SEC  SOUTH LAT.\nDECIMAL DEGR  \
# 0               25  51  14                   25.4558
# 1               25  52  44                   25.4481
# 2               25  56  07                   25.5450
# ...

# %%
prueba=pd.read_csv("WQI_prueba.csv")
prueba.head()
# Out:
#   Sample number\tPH\tEC\tTDS\tNa\tK\tCa\tMg\tNO3\tPO4\tCO3\tHCO3\tCl\tF\tError (%)
# 0  1\t7.54\t2870\t1880\t312.80\t1.60\t72.00\t113....
# 1  2\t7.80\t4470\t3070\t536.00\t46.00\t48.00\t105...
# 2  3\t7.64\t1840\t1210\t391.00\t32.00\t56.00\t88....
# 3  4\t7.88\t970.00\t640.00\t179.40\t5.90\t44.00\t...
# 4  5\t7.63\t1700\t1120\t184.00\t0.60\t60.00\t65.6...
